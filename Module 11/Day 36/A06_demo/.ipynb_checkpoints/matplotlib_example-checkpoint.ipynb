# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv")

data.head()
# Out:
# C:\Users\MCIMOLINI\AppData\Local\Temp\ipykernel_36232\3861818267.py:4: DtypeWarning: Columns (0: Suite) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv")
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
#   Assessment Class 2 Assessment Class 3  Assessment Class % 1  \
# 0                NaN                NaN                   100
# 1                NaN                NaN                   100
# 2                NaN                NaN                   100
# 3                NaN                NaN                   100
# 4                NaN                NaN                   100
#
#    Assessment Class % 2  Assessment Class % 3   Latitude   Longitude  \
# 0                   NaN                   NaN  53.576329 -113.392304
# 1                   NaN                   NaN  53.576329 -113.392304
# 2                   NaN                   NaN  53.576329 -113.392304
# 3                   NaN                   NaN  53.576329 -113.392304
# 4                   NaN                   NaN  53.576329 -113.392304
#
#                                   Point Location
# 0  POINT (-113.39230350026378 53.57632901357068)
# 1  POINT (-113.39230350026378 53.57632901357068)
# 2  POINT (-113.39230350026378 53.57632901357068)
# 3  POINT (-113.39230350026378 53.57632901357068)
# 4  POINT (-113.39230350026378 53.57632901357068)

# %%
residential_data = data[data["Tax Class"] == "Residential"] # filters our data to where Tax Class == Residential
most_expensive = residential_data.sort_values(by="Assessed Value", ascending=False)[:6]

most_expensive.head(10)
# Out:
#         Account Number Suite  House Number         Street Name  \
# 178414         3020757   NaN        2110.0       127 STREET SW
# 311936        11227628   NaN        1703.0       199 STREET NW
# 311937        11227629   NaN       18655.0        18 AVENUE NW
# 178415         3020765   NaN        1230.0       127 STREET SW
# 247886        10888381   NaN       17861.0  MERIDIAN STREET NE
# 201496         1070150   NaN        1704.0       170 STREET SW
# 301927         1108380   NaN       15623.0    CAMPBELL ROAD NW
# 201493         1070101   NaN        2340.0       184 STREET SW
# 93918         11044852   NaN       17350.0        66 STREET NW
# 163838        10003476   NaN       18350.0       127 STREET NW
#
#         Neighbourhood ID          Neighbourhood                   Ward  \
# 178414            5456.0   HERITAGE VALLEY AREA  Ipiihkoohkanipiaohtsi
# 311936            4469.0           RIVER'S EDGE          sipiwiyiniwak
# 311937            4469.0           RIVER'S EDGE          sipiwiyiniwak
# 178415            5456.0   HERITAGE VALLEY AREA  Ipiihkoohkanipiaohtsi
# 247886            2671.0                MARQUIS                   Dene
# 201496            5574.0                KESWICK              pihêsiwin
# 301927            3360.0     RAMPART INDUSTRIAL                Anirniq
# 201493            5574.0                KESWICK              pihêsiwin
# 93918             2462.0  CRYSTALLINA NERA EAST         tastawiyiniwak
# 163838            3490.0      GOODRIDGE CORNERS                Anirniq
#
#         Assessed Value    Tax Class Garage Assessment Class 1  \
# 178414        25361500  Residential      N        RESIDENTIAL
# 311936        24815000  Residential      N        RESIDENTIAL
# 311937        20778500  Residential      N        RESIDENTIAL
# 178415        16507000  Residential      N        RESIDENTIAL
# 247886        16470000  Residential      N        RESIDENTIAL
# 201496        15623000  Residential      N        RESIDENTIAL
# 301927        14555000  Residential      N        RESIDENTIAL
# 201493        14471500  Residential      N        RESIDENTIAL
# 93918         14370500  Residential      N        RESIDENTIAL
# 163838        14330000  Residential      N        RESIDENTIAL
#
#        Assessment Class 2 Assessment Class 3  Assessment Class % 1  \
# 178414         COMMERCIAL                NaN                    99
# 311936         COMMERCIAL                NaN                    99
# 311937         COMMERCIAL         COMMERCIAL                    95
# 178415                NaN                NaN                   100
# 247886         COMMERCIAL         COMMERCIAL                    79
# 201496         COMMERCIAL                NaN                    60
# 301927                NaN                NaN                   100
# 201493         COMMERCIAL         COMMERCIAL                    94
# 93918          COMMERCIAL         COMMERCIAL                    95
# 163838                NaN                NaN                   100
#
#         Assessment Class % 2  Assessment Class % 3   Latitude   Longitude  \
# 178414                   1.0                   NaN  53.413984 -113.547100
# 311936                   1.0                   NaN  53.450112 -113.658086
# 311937                   4.0                   1.0  53.450458 -113.646001
# 178415                   NaN                   NaN  53.421090 -113.547141
# 247886                  19.0                   1.0  53.641012 -113.338073
# 201496                  40.0                   NaN  53.413996 -113.620816
# 301927                   NaN                   NaN  53.617930 -113.584253
# 201493                   5.0                   1.0  53.412661 -113.647601
# 93918                    3.0                   2.0  53.638478 -113.449135
# 163838                   NaN                   NaN  53.645379 -113.552919
#
#                                         Point Location
# 178414   POINT (-113.54710019249728 53.41398370897733)
# 311936   POINT (-113.65808623620678 53.45011205733109)
# 311937   POINT (-113.64600131715767 53.45045757198648)
# 178415  POINT (-113.54714144221592 53.421089540804516)
# 247886   POINT (-113.33807292579628 53.64101211614205)
# 201496   POINT (-113.62081645984783 53.41399623816252)
# 301927   POINT (-113.5842528096102 53.617929972664726)
# 201493   POINT (-113.64760092858845 53.41266149637322)
# 93918    POINT (-113.44913453043307 53.63847780740848)
# 163838  POINT (-113.55291904581743 53.645378724811366)

# %%
most_expensive["Property Address"] = most_expensive["House Number"].astype(str) + " " + most_expensive["Street Name"]

# %%
# Set up storage for our data
property_names = most_expensive["Property Address"][:6] # [:6] gets the top 6 items.
assessed_values = most_expensive["Assessed Value"][:6]

# %%
print(property_names)
# Out:
# 178414          2110.0 127 STREET SW
# 311936          1703.0 199 STREET NW
# 311937          18655.0 18 AVENUE NW
# 178415          1230.0 127 STREET SW
# 247886    17861.0 MERIDIAN STREET NE
#                      ...
# 14943             616.0 50 STREET NW
# 14986      1130.0 MERIDIAN STREET NW
# 355723           8623.0 95 AVENUE NW
# 186307                           NaN
# 185896                           NaN
# Name: Property Address, Length: 403864, dtype: str

# %%
plt.figure(figsize=(10, 6))
plt.bar(property_names, assessed_values, color='skyblue')
plt.xlabel('Property Address')
plt.ylabel('Assessed Value')
plt.title('Top 6 Most Expensive Residential Properties')
plt.xticks(rotation=45, ha='right')  # Rotate x labels for better readability
plt.show()
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.bar(property_names, assessed_values, color='skyblue')
#       3 plt.xlabel('Property Address')
#       4 plt.ylabel('Assessed Value')
#       5 plt.title('Top 6 Most Expensive Residential Properties')
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\axes\_axes.py:2555, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2549         x = 0
#    2551 if orientation == 'vertical':
#    2552     # It is possible for y (bottom) to contain unit information.
#    2553     # However, it is also possible for y=0 for the default and height
#    2554     # to contain unit information.  This will prioritize the units of y.
# -> 2555     self._process_unit_info(
#    2556         [("x", x), ("y", y), ("y", height)], kwargs, convert=False)
#    2557     if log:
#    2558         self.set_yscale('log', nonpositive='clip')
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\axes\_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~\OneDrive - NAIT\Course Files\1252\SDEV1001\workbook_mcimolini_W2026\Module 11\Day 36\A06_demo\venv\Lib\site-packages\matplotlib\_api\__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
