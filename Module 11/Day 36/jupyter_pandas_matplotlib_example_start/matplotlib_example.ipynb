# %%
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
properties_data = pd.read_csv("C:/Users/anumz/OneDrive/Documents/GitHub/workbook_mcimolini_W2026/Module 11/Day 36/jupyter_pandas_matplotlib_example_start/data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv")
# Out:
# C:\Users\anumz\AppData\Local\Temp\ipykernel_25724\1299041767.py:1: DtypeWarning: Columns (0: Suite) have mixed types. Specify dtype option on import or set low_memory=False.
#   properties_data = pd.read_csv("C:/Users/anumz/OneDrive/Documents/GitHub/workbook_mcimolini_W2026/Module 11/Day 36/jupyter_pandas_matplotlib_example_start/data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv")

# %%
properties_data.head()
# Out:
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
# ...

# %%
residential_data = properties_data[properties_data['Tax Class'] == "Residential"]
residential_data.head()
# Out:
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
# ...

# %%
top_6_expensive = residential_data.sort_values(by="Assessed Value",ascending=False)[:6]

# %%
top_6_expensive.head(10)
# Out:
#         Account Number Suite  House Number         Street Name  \
# 178414         3020757   NaN        2110.0       127 STREET SW
# 311936        11227628   NaN        1703.0       199 STREET NW
# 311937        11227629   NaN       18655.0        18 AVENUE NW
# 178415         3020765   NaN        1230.0       127 STREET SW
# 247886        10888381   NaN       17861.0  MERIDIAN STREET NE
# 201496         1070150   NaN        1704.0       170 STREET SW
#
#         Neighbourhood ID         Neighbourhood                   Ward  \
# 178414            5456.0  HERITAGE VALLEY AREA  Ipiihkoohkanipiaohtsi
# 311936            4469.0          RIVER'S EDGE          sipiwiyiniwak
# 311937            4469.0          RIVER'S EDGE          sipiwiyiniwak
# 178415            5456.0  HERITAGE VALLEY AREA  Ipiihkoohkanipiaohtsi
# 247886            2671.0               MARQUIS                   Dene
# 201496            5574.0               KESWICK              pihêsiwin
#
# ...

# %%
top_6_expensive['Property Address'] = top_6_expensive['House Number'].astype(str) + ' ' + top_6_expensive['Street Name']

# %%
property_names = top_6_expensive['Property Address']

# %%
assessed_values = top_6_expensive['Assessed Value']

# %%
plt.figure(figsize=(10,6))
plt.bar(property_names,assessed_values,color='skyblue')
plt.xlabel('Property Address')
plt.ylabel('Assessed Value')
plt.title('Top 6 Expensive Residential Properties')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(property_names,assessed_values,marker='o',linestyle='-',color='orange')
plt.xlabel('Property Address')
plt.ylabel('Assessed Value')
plt.title('Top 6 Expensive Residential Properties- Line Chart')
plt.xticks(rotation=45,ha="right")
plt.grid(True)
plt.show()

# %%
avg_assessed_by_neighbourhood = residential_data.groupby('Neighbourhood')['Assessed Value'].mean().sort_values(ascending=False)[:10]
avg_assessed_by_neighbourhood.head()
# Out:
# Neighbourhood
# HERITAGE VALLEY AREA          2.093425e+07
# MISTATIM INDUSTRIAL           7.885500e+06
# GOODRIDGE CORNERS             3.376444e+06
# RAMPART INDUSTRIAL            3.075250e+06
# RIVER VALLEY FORT EDMONTON    2.443929e+06
# Name: Assessed Value, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.bar(avg_assessed_by_neighbourhood.index,avg_assessed_by_neighbourhood.values, color='lightgreen')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Assessed Value')
plt.title('Top 10 Neighbourhoods by Average Assessed Value')
plt.xticks(rotation=45,ha='right')
plt.show()
