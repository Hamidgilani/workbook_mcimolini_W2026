# %%
import pandas as pd #as pd just changes the access name

# %%
property_data = pd.read_csv("data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv") # this is a DataFrame
# Out:
# C:\Users\mcimo\AppData\Local\Temp\ipykernel_22820\2313772612.py:1: DtypeWarning: Columns (0: Suite) have mixed types. Specify dtype option on import or set low_memory=False.
#   property_data = pd.read_csv("data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv") # this is a DataFrame

# %%
property_data.head() # pulls the first 5 data rows
# Out:
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
# ...

# %%
property_data.info() # provides information about the DataFrame
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 431706 entries, 0 to 431705
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Account Number        431706 non-null  int64
#  1   Suite                 82839 non-null   object
#  2   House Number          386360 non-null  float64
#  3   Street Name           386360 non-null  str
#  4   Neighbourhood ID      423470 non-null  float64
#  5   Neighbourhood         431706 non-null  str
#  6   Ward                  423470 non-null  str
#  7   Assessed Value        431706 non-null  int64
#  8   Tax Class             431706 non-null  str
#  9   Garage                431706 non-null  str
#  10  Assessment Class 1    431706 non-null  str
#  11  Assessment Class 2    1096 non-null    str
#  12  Assessment Class 3    283 non-null     str
#  13  Assessment Class % 1  431706 non-null  int64
#  14  Assessment Class % 2  1096 non-null    float64
# ...

# %%
property_data.shape # returns (rows, columns)
# Out:
# (431706, 19)

# %%
property_data.describe() # provides basic data statistics
# Out:
#        Account Number   House Number  Neighbourhood ID  Assessed Value  \
# count    4.317060e+05  386360.000000     423470.000000    4.317060e+05
# mean     7.932009e+06    7715.353792       4274.007878    5.097698e+05
# std      3.266791e+06    5494.706696       1756.729000    3.770018e+06
# min      1.001007e+06       1.000000       1010.000000    0.000000e+00
# 25%      4.763971e+06    2513.750000       2660.000000    1.800000e+05
# 50%      9.985830e+06    7916.000000       4487.000000    3.690000e+05
# 75%      1.027426e+07   11431.000000       5579.000000    5.005000e+05
# max      1.131654e+07   51175.000000       8889.000000    1.289650e+09
#
#        Assessment Class % 1  Assessment Class % 2  Assessment Class % 3  \
# count         431706.000000           1096.000000            283.000000
# mean              99.952975             17.537409              3.243816
# std                1.214058             15.312706              3.522056
# ...

# %%
property_data["Neighbourhood"].unique() # we can use our column names as keys to access data. unique returns the unique entries
# Out:
# <StringArray>
# [                   'ABBOTTSFIELD',                          'ALBANY',
#                   'ALBERTA AVENUE',         'ALBERTA PARK INDUSTRIAL',
#                            'ALCES',                      'ALDERGROVE',
#                           'ALLARD',                       'ALLENDALE',
#                        'AMBLESIDE',                  'ANTHONY HENDAY',
#  ...
#                       'WINDERMERE',                 'WINDERMERE AREA',
#                     'WINDSOR PARK', 'WINTERBURN INDUSTRIAL AREA EAST',
#  'WINTERBURN INDUSTRIAL AREA WEST',                       'WOODCROFT',
#         'YELLOWHEAD CORRIDOR EAST',        'YELLOWHEAD CORRIDOR WEST',
#                             'YORK',           'YOUNGSTOWN INDUSTRIAL']
# Length: 406, dtype: str

# %%
downtown_properties = property_data[property_data["Neighbourhood"] == 'DOWNTOWN'] # pulls all data where neighbourgood == downtown
print(f"Number of properties in downtown {downtown_properties.shape[0]}") # lists the # of properties

downtown_properties.head()
# Out:
# Number of properties in downtown 10307
#         Account Number Suite  House Number       Street Name  \
# 106995         1018019   NaN       10040.0     103 STREET NW
# 106996         1018027   NaN       10405.0  JASPER AVENUE NW
# 106997         1018035   NaN       10808.0      99 AVENUE NW
# 106998         1024140   NaN        9839.0  JASPER AVENUE NW
# 106999         1033141   NaN       10820.0     100 AVENUE NW
#
#         Neighbourhood ID Neighbourhood       Ward  Assessed Value  \
# 106995            1090.0      DOWNTOWN  O-day'min             500
# 106996            1090.0      DOWNTOWN  O-day'min               0
# 106997            1090.0      DOWNTOWN  O-day'min        16343500
# 106998            1090.0      DOWNTOWN  O-day'min          150000
# 106999            1090.0      DOWNTOWN  O-day'min        12290500
#
#               Tax Class Garage Assessment Class 1 Assessment Class 2  \
# 106995  Non Residential      N         COMMERCIAL                NaN
# ...

# %%
sorted_downtown = downtown_properties.sort_values(by="Assessed Value", ascending=False)
sorted_downtown.head()
# Out:
#         Account Number Suite  House Number    Street Name  Neighbourhood ID  \
# 117266        11012019   NaN       10700.0  104 AVENUE NW            1090.0
# 107029         3010113   NaN       10111.0  104 AVENUE NW            1090.0
# 116496        10854737   NaN       10220.0  103 AVENUE NW            1090.0
# 116107        10841805   NaN        9804.0  107 STREET NW            1090.0
# 115226        10507383   NaN       10175.0  101 STREET NW            1090.0
#
#        Neighbourhood       Ward  Assessed Value        Tax Class Garage  \
# 117266      DOWNTOWN  O-day'min       342370500  Non Residential      N
# 107029      DOWNTOWN  O-day'min       303790500  Non Residential      N
# 116496      DOWNTOWN  O-day'min       284566500  Non Residential      N
# 116107      DOWNTOWN  O-day'min       269688500  Non Residential      N
# 115226      DOWNTOWN  O-day'min       269044500  Non Residential      N
#
#        Assessment Class 1 Assessment Class 2 Assessment Class 3  \
# ...

# %%
print(sorted_downtown[:10]) # I can still treat this as a list, it's just not as nice to look at.
# Out:
#         Account Number Suite  House Number       Street Name  \
# 117266        11012019   NaN       10700.0     104 AVENUE NW
# 107029         3010113   NaN       10111.0     104 AVENUE NW
# 116496        10854737   NaN       10220.0     103 AVENUE NW
# 116107        10841805   NaN        9804.0     107 STREET NW
# 115226        10507383   NaN       10175.0     101 STREET NW
# 117287        11161319   NaN       10423.0     101 STREET NW
# 107219         3121522   NaN        9700.0  JASPER AVENUE NW
# 109930         9981060   NaN       10155.0     102 STREET NW
# 107004         1066331   NaN       10180.0     101 STREET NW
# 115231        10713425   NaN       10215.0     108 STREET NW
#
#         Neighbourhood ID Neighbourhood       Ward  Assessed Value  \
# 117266            1090.0      DOWNTOWN  O-day'min       342370500
# 107029            1090.0      DOWNTOWN  O-day'min       303790500
# 116496            1090.0      DOWNTOWN  O-day'min       284566500
# ...

# %%
print(sorted_downtown[["House Number", "Street Name", "Assessed Value"]][:10]) # acts like an SQL Select
# Out:
#         House Number       Street Name  Assessed Value
# 117266       10700.0     104 AVENUE NW       342370500
# 107029       10111.0     104 AVENUE NW       303790500
# 116496       10220.0     103 AVENUE NW       284566500
# 116107        9804.0     107 STREET NW       269688500
# 115226       10175.0     101 STREET NW       269044500
# 117287       10423.0     101 STREET NW       255188500
# 107219        9700.0  JASPER AVENUE NW       146280500
# 109930       10155.0     102 STREET NW       138813500
# 107004       10180.0     101 STREET NW       134928000
# 115231       10215.0     108 STREET NW       110509500

# %%
sorted_properties = property_data.sort_values(by="Assessed Value", ascending = False)
sorted_properties.head()
# Out:
#         Account Number Suite  House Number           Street Name  \
# 357664         3054384   NaN        8882.0         170 STREET NW
# 388670         7012578   NaN       11404.0          89 AVENUE NW
# 388682         9992482   NaN       11305.0          83 AVENUE NW
# 388683         9996778   NaN       11203.0          87 AVENUE NW
# 388661         4025383   NaN       11404.0  UNIVERSITY AVENUE NW
#
#         Neighbourhood ID          Neighbourhood           Ward  \
# 357664            4520.0              SUMMERLEA  sipiwiyiniwak
# 388670            5520.0  UNIVERSITY OF ALBERTA       papastew
# 388682            5520.0  UNIVERSITY OF ALBERTA       papastew
# 388683            5520.0  UNIVERSITY OF ALBERTA       papastew
# 388661            5520.0  UNIVERSITY OF ALBERTA       papastew
#
#         Assessed Value        Tax Class Garage Assessment Class 1  \
# 357664      1289649500  Non Residential      N         COMMERCIAL
# ...

# %%
residential_properties = sorted_properties[sorted_properties["Tax Class"] == 'Residential']
residential_properties = residential_properties[residential_properties["Assessment Class 2"] != "COMMERCIAL"]
residential_properties.head()
# Out:
#         Account Number Suite  House Number       Street Name  \
# 178415         3020765   NaN        1230.0     127 STREET SW
# 301927         1108380   NaN       15623.0  CAMPBELL ROAD NW
# 163838        10003476   NaN       18350.0     127 STREET NW
# 48426         10884511   NaN        9323.0    101A AVENUE NW
# 219550         1868496   NaN        9703.0     185 STREET NW
#
#         Neighbourhood ID         Neighbourhood                   Ward  \
# 178415            5456.0  HERITAGE VALLEY AREA  Ipiihkoohkanipiaohtsi
# 301927            3360.0    RAMPART INDUSTRIAL                Anirniq
# 163838            3490.0     GOODRIDGE CORNERS                Anirniq
# 48426             1020.0          BOYLE STREET              O-day'min
# 219550            4240.0              LA PERLE            Nakota Isga
#
#         Assessed Value    Tax Class Garage Assessment Class 1  \
# 178415        16507000  Residential      N        RESIDENTIAL
# ...
