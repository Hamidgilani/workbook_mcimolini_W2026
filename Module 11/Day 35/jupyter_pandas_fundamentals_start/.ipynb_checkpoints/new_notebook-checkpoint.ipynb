# %%
import pandas as pd

# %%
property_data = pd.read_csv("/Users/hamid/Documents/GitHub/workbook_mcimolini_W2026/Module 11/Day 35/jupyter_pandas_fundamentals_start/data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv",low_memory=False)

# %%
property_data.head()
# Out:
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
# ...

# %%
property_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431706 entries, 0 to 431705
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Account Number        431706 non-null  int64
#  1   Suite                 82839 non-null   object
#  2   House Number          386360 non-null  float64
#  3   Street Name           386360 non-null  object
#  4   Neighbourhood ID      423470 non-null  float64
#  5   Neighbourhood         431706 non-null  object
#  6   Ward                  423470 non-null  object
#  7   Assessed Value        431706 non-null  int64
#  8   Tax Class             431706 non-null  object
#  9   Garage                431706 non-null  object
#  10  Assessment Class 1    431706 non-null  object
#  11  Assessment Class 2    1096 non-null    object
#  12  Assessment Class 3    283 non-null     object
#  13  Assessment Class % 1  431706 non-null  int64
# ...

# %%
property_data.shape
# Out:
# (431706, 19)

# %%
property_data.describe()
# Out:
#        Account Number   House Number  Neighbourhood ID  Assessed Value  \
# count    4.317060e+05  386360.000000     423470.000000    4.317060e+05
# mean     7.932009e+06    7715.353792       4274.007878    5.097698e+05
# std      3.266791e+06    5494.706696       1756.729000    3.770018e+06
# min      1.001007e+06       1.000000       1010.000000    0.000000e+00
# 25%      4.763971e+06    2513.750000       2660.000000    1.800000e+05
# 50%      9.985830e+06    7916.000000       4487.000000    3.690000e+05
# 75%      1.027426e+07   11431.000000       5579.000000    5.005000e+05
# max      1.131654e+07   51175.000000       8889.000000    1.289650e+09
#
#        Assessment Class % 1  Assessment Class % 2  Assessment Class % 3  \
# count         431706.000000           1096.000000            283.000000
# mean              99.952975             17.537409              3.243816
# std                1.214058             15.312706              3.522056
# ...

# %%
property_data["Neighbourhood"].unique()
# Out:
# array(['ABBOTTSFIELD', 'ALBANY', 'ALBERTA AVENUE',
#        'ALBERTA PARK INDUSTRIAL', 'ALCES', 'ALDERGROVE', 'ALLARD',
#        'ALLENDALE', 'AMBLESIDE', 'ANTHONY HENDAY',
#        'ANTHONY HENDAY BIG LAKE', 'ANTHONY HENDAY CASTLEDOWNS',
#        'ANTHONY HENDAY CLAREVIEW', 'ANTHONY HENDAY ENERGY PARK',
#        'ANTHONY HENDAY HORSE HILL', 'ANTHONY HENDAY LAKE DISTRICT',
#        'ANTHONY HENDAY MISTATIM', 'ANTHONY HENDAY RAMPART',
#        'ANTHONY HENDAY SOUTH', 'ANTHONY HENDAY SOUTH BLACKBURNE',
#        'ANTHONY HENDAY SOUTH WEST', 'ANTHONY HENDAY SOUTHEAST',
#        'ANTHONY HENDAY TERWILLEGAR', 'ARGYLL', 'ARMSTRONG INDUSTRIAL',
#        'ASPEN GARDENS', 'ASTER', 'ATHLONE', 'AVONMORE', 'BALWIN',
#        'BANNERMAN', 'BARANOW', 'BATURYN', 'BEACON HEIGHTS', 'BEARSPAW',
#        'BEAUMARIS', 'BELGRAVIA', 'BELLE RIVE', 'BELLEVUE', 'BELMEAD',
#        'BELMONT', 'BELVEDERE', 'BERGMAN', 'BEVERLY HEIGHTS', 'BISSET',
#        'BLACKBURNE', 'BLACKMUD CREEK', 'BLACKMUD CREEK RAVINE',
# ...

# %%
downtown_properties = property_data[property_data["Neighbourhood"]=="DOWNTOWN"]

# %%
print(f"Number of properties in downtown {downtown_properties.shape[0]}")
# Out:
# Number of properties in downtown 10307

# %%
downtown_properties.head()
# Out:
#         Account Number Suite  House Number       Street Name  \
# 106995         1018019   NaN       10040.0     103 STREET NW
# 106996         1018027   NaN       10405.0  JASPER AVENUE NW
# 106997         1018035   NaN       10808.0      99 AVENUE NW
# 106998         1024140   NaN        9839.0  JASPER AVENUE NW
# 106999         1033141   NaN       10820.0     100 AVENUE NW
#
#         Neighbourhood ID Neighbourhood       Ward  Assessed Value  \
# 106995            1090.0      DOWNTOWN  O-day'min             500
# 106996            1090.0      DOWNTOWN  O-day'min               0
# 106997            1090.0      DOWNTOWN  O-day'min        16343500
# 106998            1090.0      DOWNTOWN  O-day'min          150000
# 106999            1090.0      DOWNTOWN  O-day'min        12290500
#
#               Tax Class Garage Assessment Class 1 Assessment Class 2  \
# 106995  Non Residential      N         COMMERCIAL                NaN
# ...

# %%
sorted_downtown = downtown_properties.sort_values(by="Assessed Value",ascending=False)
sorted_downtown.head()
# Out:
#         Account Number Suite  House Number    Street Name  Neighbourhood ID  \
# 117266        11012019   NaN       10700.0  104 AVENUE NW            1090.0
# 107029         3010113   NaN       10111.0  104 AVENUE NW            1090.0
# 116496        10854737   NaN       10220.0  103 AVENUE NW            1090.0
# 116107        10841805   NaN        9804.0  107 STREET NW            1090.0
# 115226        10507383   NaN       10175.0  101 STREET NW            1090.0
#
#        Neighbourhood       Ward  Assessed Value        Tax Class Garage  \
# 117266      DOWNTOWN  O-day'min       342370500  Non Residential      N
# 107029      DOWNTOWN  O-day'min       303790500  Non Residential      N
# 116496      DOWNTOWN  O-day'min       284566500  Non Residential      N
# 116107      DOWNTOWN  O-day'min       269688500  Non Residential      N
# 115226      DOWNTOWN  O-day'min       269044500  Non Residential      N
#
#        Assessment Class 1 Assessment Class 2 Assessment Class 3  \
# ...

# %%
print(sorted_downtown[:10])
# Out:
#         Account Number Suite  House Number       Street Name  \
# 117266        11012019   NaN       10700.0     104 AVENUE NW
# 107029         3010113   NaN       10111.0     104 AVENUE NW
# 116496        10854737   NaN       10220.0     103 AVENUE NW
# 116107        10841805   NaN        9804.0     107 STREET NW
# 115226        10507383   NaN       10175.0     101 STREET NW
# 117287        11161319   NaN       10423.0     101 STREET NW
# 107219         3121522   NaN        9700.0  JASPER AVENUE NW
# 109930         9981060   NaN       10155.0     102 STREET NW
# 107004         1066331   NaN       10180.0     101 STREET NW
# 115231        10713425   NaN       10215.0     108 STREET NW
#
#         Neighbourhood ID Neighbourhood       Ward  Assessed Value  \
# 117266            1090.0      DOWNTOWN  O-day'min       342370500
# 107029            1090.0      DOWNTOWN  O-day'min       303790500
# 116496            1090.0      DOWNTOWN  O-day'min       284566500
# ...

# %%
print(sorted_downtown[["House Number","Street Name","Assessed Value"]][:10])
# Out:
#         House Number       Street Name  Assessed Value
# 117266       10700.0     104 AVENUE NW       342370500
# 107029       10111.0     104 AVENUE NW       303790500
# 116496       10220.0     103 AVENUE NW       284566500
# 116107        9804.0     107 STREET NW       269688500
# 115226       10175.0     101 STREET NW       269044500
# 117287       10423.0     101 STREET NW       255188500
# 107219        9700.0  JASPER AVENUE NW       146280500
# 109930       10155.0     102 STREET NW       138813500
# 107004       10180.0     101 STREET NW       134928000
# 115231       10215.0     108 STREET NW       110509500

# %%
sorted_downtown['Assessed Value in Millions'] = sorted_downtown['Assessed Value']/1000000

# %%
print(sorted_downtown[["House Number","Street Name","Assessed Value in Millions"]][:10])
# Out:
#         House Number       Street Name  Assessed Value in Millions
# 117266       10700.0     104 AVENUE NW                    342.3705
# 107029       10111.0     104 AVENUE NW                    303.7905
# 116496       10220.0     103 AVENUE NW                    284.5665
# 116107        9804.0     107 STREET NW                    269.6885
# 115226       10175.0     101 STREET NW                    269.0445
# 117287       10423.0     101 STREET NW                    255.1885
# 107219        9700.0  JASPER AVENUE NW                    146.2805
# 109930       10155.0     102 STREET NW                    138.8135
# 107004       10180.0     101 STREET NW                    134.9280
# 115231       10215.0     108 STREET NW                    110.5095

# %%
# for ellerslie 
ellerslie_properties = property_data[property_data["Neighbourhood"]=="ELLERSLIE"]
ellerslie_properties.head()
# Out:
#         Account Number Suite  House Number        Street Name  \
# 129818         1068840   NaN         830.0       66 STREET SW
# 129819         1068857   NaN         730.0       66 STREET SW
# 129820         1068865   NaN        6731.0        6 AVENUE SW
# 129821         1068907   NaN        7130.0  ELLERSLIE ROAD SW
# 129822         1068915   NaN         430.0       71 STREET SW
#
#         Neighbourhood ID Neighbourhood     Ward  Assessed Value    Tax Class  \
# 129818            6211.0     ELLERSLIE  Karhiio          780000  Residential
# 129819            6211.0     ELLERSLIE  Karhiio          682500  Residential
# 129820            6211.0     ELLERSLIE  Karhiio          817000  Residential
# 129821            6211.0     ELLERSLIE  Karhiio          985000  Residential
# 129822            6211.0     ELLERSLIE  Karhiio          996500  Residential
#
#        Garage Assessment Class 1 Assessment Class 2 Assessment Class 3  \
# ...

# %%
print(f"Number of properties in Ellerslie {ellerslie_properties.shape[0]}")
# Out:
# Number of properties in Ellerslie 2425

# %%
sorted_ellerslie = ellerslie_properties.sort_values(by="Assessed Value",ascending=False)
sorted_ellerslie.head()
# Out:
#         Account Number Suite  House Number        Street Name  \
# 132242        11142381   NaN        6830.0  ELLERSLIE ROAD SW
# 130162         9997633   NaN         248.0   EDWARDS DRIVE SW
# 132241        11142380   NaN        7030.0  ELLERSLIE ROAD SW
# 129849         3889862   NaN         707.0       75 STREET SW
# 129832         1069046   NaN        6650.0        4 AVENUE SW
#
#         Neighbourhood ID Neighbourhood     Ward  Assessed Value  \
# 132242            6211.0     ELLERSLIE  Karhiio        20806500
# 130162            6211.0     ELLERSLIE  Karhiio        10180500
# 132241            6211.0     ELLERSLIE  Karhiio         4885500
# 129849            6211.0     ELLERSLIE  Karhiio         4220500
# 129832            6211.0     ELLERSLIE  Karhiio         3692500
#
#                 Tax Class Garage Assessment Class 1 Assessment Class 2  \
# 132242    Non Residential      N         COMMERCIAL                NaN
# ...

# %%
print(f"{ellerslie_properties[:10]}")
# Out:
#         Account Number Suite  House Number        Street Name  \
# 129818         1068840   NaN         830.0       66 STREET SW
# 129819         1068857   NaN         730.0       66 STREET SW
# 129820         1068865   NaN        6731.0        6 AVENUE SW
# 129821         1068907   NaN        7130.0  ELLERSLIE ROAD SW
# 129822         1068915   NaN         430.0       71 STREET SW
# 129823         1068923   NaN        7120.0        4 AVENUE SW
# 129824         1068931   NaN         230.0       71 STREET SW
# 129825         1068956   NaN        6920.0        2 AVENUE SW
# 129826         1068964   NaN        6720.0        2 AVENUE SW
# 129827         1068980   NaN         120.0       66 STREET SW
#
#         Neighbourhood ID Neighbourhood     Ward  Assessed Value  \
# 129818            6211.0     ELLERSLIE  Karhiio          780000
# 129819            6211.0     ELLERSLIE  Karhiio          682500
# 129820            6211.0     ELLERSLIE  Karhiio          817000
# ...

# %%
print(sorted_ellerslie[["House Number","Street Name","Assessed Value"]][:10])
# Out:
#         House Number        Street Name  Assessed Value
# 132242        6830.0  ELLERSLIE ROAD SW        20806500
# 130162         248.0   EDWARDS DRIVE SW        10180500
# 132241        7030.0  ELLERSLIE ROAD SW         4885500
# 129849         707.0       75 STREET SW         4220500
# 129832        6650.0        4 AVENUE SW         3692500
# 129848         811.0       75 STREET SW         3255000
# 129827         120.0       66 STREET SW         3038500
# 129850         635.0       75 STREET SW         2696500
# 131713         371.0       91 STREET SW         2615500
# 129847        6704.0  ELLERSLIE ROAD SW         2308500

# %%
sorted_ellerslie['Assessed Value in Millions'] = sorted_ellerslie["Assessed Value"]/1000000

# %%
print(sorted_ellerslie[["House Number","Street Name","Assessed Value in Millions"]][:10])
# Out:
#         House Number        Street Name  Assessed Value in Millions
# 132242        6830.0  ELLERSLIE ROAD SW                     20.8065
# 130162         248.0   EDWARDS DRIVE SW                     10.1805
# 132241        7030.0  ELLERSLIE ROAD SW                      4.8855
# 129849         707.0       75 STREET SW                      4.2205
# 129832        6650.0        4 AVENUE SW                      3.6925
# 129848         811.0       75 STREET SW                      3.2550
# 129827         120.0       66 STREET SW                      3.0385
# 129850         635.0       75 STREET SW                      2.6965
# 131713         371.0       91 STREET SW                      2.6155
# 129847        6704.0  ELLERSLIE ROAD SW                      2.3085
